# %%
#import dependencies
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#paths to load csv files
VIO_Data_1= pd.read_csv("Resources/VIO_Data_1_Final.csv")
VIO_Data_2= pd.read_csv("Resources/VIO_Data_2_Final.csv")
VIO_US_Data = pd.read_csv("Resources/VIO_US_Data.csv")
ACES_Data = pd.read_csv("Resources/ACES_Data.csv")
Parts_Data = pd.read_csv("Resources/Parts_Data.csv")
Population_Data = pd.read_csv("Resources/State_Population.csv")

#merge the data into a single data set
VIO_Data_Complete = pd.merge(VIO_Data_1, VIO_Data_2, how="outer")
print(f'The length of VIO Data 1 is: {len(VIO_Data_1)} rows.')
print(f'The length of VIO Data 2 is: {len(VIO_Data_2)} rows.')
print(f'The length of merged VIO Data is: {len(VIO_Data_Complete)} rows.')
# Out:
# The length of VIO Data 1 is: 114382 rows.
# The length of VIO Data 2 is: 155815 rows.
# The length of merged VIO Data is: 270197 rows.

# %%
#print out the first 5 rows of the data set
VIO_Data_Complete.head()
# Out:
#    VehicleID          State  Year        Make   VIO
# 0        545      Wisconsin  1993  Land Rover   2.0
# 1        545        Montana  1993  Land Rover   9.0
# 2        545  New Hampshire  1993  Land Rover   6.0
# 3        545        Wyoming  1993  Land Rover   2.0
# 4        545        Florida  1993  Land Rover  14.0

# %%
#display counts of rows by column to determine if we need to drop any missing values
VIO_Data_Complete.count()
# Out:
# VehicleID    270197
# State        268231
# Year         270197
# Make         270197
# VIO          268231
# dtype: int64

# %%
#we found that there were blank rows in the State and VIO columns, so we are dropping all blanks
VIO_Data_Clean = VIO_Data_Complete.dropna(how="any")

#verify that the counts are now correct
VIO_Data_Clean.count()
# Out:
# VehicleID    268231
# State        268231
# Year         268231
# Make         268231
# VIO          268231
# dtype: int64

# %%
#check data types of the VIO data set
VIO_Data_Clean.dtypes
# Out:
# VehicleID      int64
# State         object
# Year           int64
# Make          object
# VIO          float64
# dtype: object

# %%
#add age of cars column
VIO_Data_Clean['Age'] = 2019 - VIO_Data_Clean['Year']
VIO_Data_Clean.head()
# Out:
# /Users/whitneycollins/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    VehicleID          State  Year        Make   VIO  Age
# 0        545      Wisconsin  1993  Land Rover   2.0   26
# 1        545        Montana  1993  Land Rover   9.0   26
# 2        545  New Hampshire  1993  Land Rover   6.0   26
# 3        545        Wyoming  1993  Land Rover   2.0   26
# 4        545        Florida  1993  Land Rover  14.0   26

# %%
Makes = VIO_Data_Clean.groupby('Make')
Makes.head()
# Out:
#         VehicleID          State  Year           Make    VIO  Age
# 0             545      Wisconsin  1993     Land Rover    2.0   26
# 1             545        Montana  1993     Land Rover    9.0   26
# 2             545  New Hampshire  1993     Land Rover    6.0   26
# 3             545        Wyoming  1993     Land Rover    2.0   26
# 4             545        Florida  1993     Land Rover   14.0   26
# 398        238632      Wisconsin  2017         Jaguar   54.0    2
# 399        238632        Montana  2017         Jaguar    4.0    2
# 400        238632  New Hampshire  2017         Jaguar   16.0    2
# 401        238632        Wyoming  2017         Jaguar    6.0    2
# 402        238632        Florida  2017         Jaguar  807.0    2
# 495        240890      Wisconsin  2017            BMW   31.0    2
# 496        240890        Montana  2017            BMW    3.0    2
# 497        240890  New Hampshire  2017            BMW   21.0    2
# 498        240890        Florida  2017            BMW   71.0    2
# 499        240890          Idaho  2017            BMW    7.0    2
# 642        234146      Wisconsin  2016           Mini   38.0    3
# 643        234146        Montana  2016           Mini    3.0    3
# 644        234146  New Hampshire  2016           Mini   20.0    3
# 645        234146        Wyoming  2016           Mini    1.0    3
# 646        234146        Florida  2016           Mini  503.0    3
# 1594       228810      Wisconsin  2016           Audi   30.0    3
# 1595       228810        Montana  2016           Audi    7.0    3
# 1596       228810  New Hampshire  2016           Audi   21.0    3
# 1597       228810        Wyoming  2016           Audi    4.0    3
# 1598       228810        Florida  2016           Audi   67.0    3
# 114382      74157     New Jersey  2009        Porsche   25.0   10
# 114383      74157       Colorado  2009        Porsche   17.0   10
# 114384      74157     California  2009        Porsche  108.0   10
# 114385      74157       Virginia  2009        Porsche   11.0   10
# 114386      74157       Kentucky  2009        Porsche    3.0   10
# 114454     191527     New Jersey  2012     Volkswagen   93.0    7
# 114455     191527       Colorado  2012     Volkswagen  120.0    7
# 114456     191527     California  2012     Volkswagen  338.0    7
# 114457     191527       Virginia  2012     Volkswagen   86.0    7
# 114458     191527       Kentucky  2012     Volkswagen   18.0    7
# 114555     248919     New Jersey  2018  Mercedes-Benz   18.0    1
# 114556     248919       Colorado  2018  Mercedes-Benz   15.0    1
# 114557     248919     California  2018  Mercedes-Benz  388.0    1
# 114558     248919       Virginia  2018  Mercedes-Benz   10.0    1
# 114559     248919       Kentucky  2018  Mercedes-Benz    4.0    1
# 115267     227360     New Jersey  2016          Volvo  113.0    3
# 115268     227360       Colorado  2016          Volvo  121.0    3
# 115269     227360     California  2016          Volvo  219.0    3
# 115270     227360       Virginia  2016          Volvo   69.0    3
# 115271     227360       Kentucky  2016          Volvo   14.0    3
# 192833      15525     New Jersey  1985           Saab   13.0   34
# 192834      15525       Colorado  1985           Saab   26.0   34
# 192835      15525     California  1985           Saab   34.0   34
# 192836      15525       Virginia  1985           Saab   23.0   34
# 192837      15525       Kentucky  1985           Saab    1.0   34

# %%
Make_VIO = Makes['VIO'].sum()
Make_VIO
# Out:
# Make
# Audi             2047227.0
# BMW              4460541.0
# Jaguar            456487.0
# Land Rover        726037.0
# Mercedes-Benz    4589723.0
# Mini              707000.0
# Porsche           680758.0
# Saab              235215.0
# Volkswagen       4723686.0
# Volvo            1524833.0
# Name: VIO, dtype: float64

# %%
###Data Frame

#put all the variables into a dataframe named school_summary_df
Makes_VIO_Summary = pd.DataFrame({"Total VIO": Make_VIO})

#remove the display of the index name
#print the dataframe, showing all rows
Makes_VIO_Summary = Makes_VIO_Summary.sort_values('Total VIO', ascending = False)
Makes_VIO_Summary
# Out:
#                Total VIO
# Make
# Volkswagen     4723686.0
# Mercedes-Benz  4589723.0
# BMW            4460541.0
# Audi           2047227.0
# Volvo          1524833.0
# Land Rover      726037.0
# Mini            707000.0
# Porsche         680758.0
# Jaguar          456487.0
# Saab            235215.0

# %%
Small_VIO = VIO_Data_Clean.groupby(['Make','VehicleID'])
Small_VIO.head()
# Out:
#         VehicleID          State  Year           Make    VIO  Age
# 0             545      Wisconsin  1993     Land Rover    2.0   26
# 1             545        Montana  1993     Land Rover    9.0   26
# 2             545  New Hampshire  1993     Land Rover    6.0   26
# 3             545        Wyoming  1993     Land Rover    2.0   26
# 4             545        Florida  1993     Land Rover   14.0   26
# 46            547      Wisconsin  1995     Land Rover    7.0   24
# 47            547        Montana  1995     Land Rover   20.0   24
# 48            547  New Hampshire  1995     Land Rover    6.0   24
# 49            547        Wyoming  1995     Land Rover    3.0   24
# 50            547        Florida  1995     Land Rover   82.0   24
# 96            546      Wisconsin  1994     Land Rover    9.0   25
# 97            546        Montana  1994     Land Rover   14.0   25
# 98            546  New Hampshire  1994     Land Rover   18.0   25
# 99            546        Wyoming  1994     Land Rover   13.0   25
# 100           546        Florida  1994     Land Rover   94.0   25
# 146           548      Wisconsin  1997     Land Rover   16.0   22
# 147           548        Montana  1997     Land Rover   25.0   22
# 148           548  New Hampshire  1997     Land Rover   17.0   22
# 149           548        Wyoming  1997     Land Rover    8.0   22
# 150           548        Florida  1997     Land Rover  176.0   22
# 196         15905      Wisconsin  1996     Land Rover    6.0   23
# 197         15905        Montana  1996     Land Rover   12.0   23
# 198         15905  New Hampshire  1996     Land Rover    3.0   23
# 199         15905        Wyoming  1996     Land Rover    1.0   23
# 200         15905        Florida  1996     Land Rover   41.0   23
# 247         15911      Wisconsin  1997     Land Rover    1.0   22
# 248         15911        Montana  1997     Land Rover    5.0   22
# 249         15911  New Hampshire  1997     Land Rover    4.0   22
# 250         15911        Wyoming  1997     Land Rover    2.0   22
# 251         15911        Florida  1997     Land Rover   22.0   22
# ...           ...            ...   ...            ...    ...  ...
# 269912     240977     New Jersey  2017  Mercedes-Benz   76.0    2
# 269913     240977       Colorado  2017  Mercedes-Benz   37.0    2
# 269914     240977     California  2017  Mercedes-Benz  606.0    2
# 269915     240977       Virginia  2017  Mercedes-Benz   28.0    2
# 269916     240977       Kentucky  2017  Mercedes-Benz    7.0    2
# 269960     212806     New Jersey  2015  Mercedes-Benz   50.0    4
# 269961     212806       Colorado  2015  Mercedes-Benz   25.0    4
# 269962     212806     California  2015  Mercedes-Benz  369.0    4
# 269963     212806       Virginia  2015  Mercedes-Benz   19.0    4
# 269964     212806       Kentucky  2015  Mercedes-Benz    5.0    4
# 270009     193202     New Jersey  2013  Mercedes-Benz   33.0    6
# 270010     193202       Colorado  2013  Mercedes-Benz   19.0    6
# 270011     193202     California  2013  Mercedes-Benz  309.0    6
# 270012     193202       Virginia  2013  Mercedes-Benz   14.0    6
# 270013     193202       Kentucky  2013  Mercedes-Benz    3.0    6
# 270057     258175     New Jersey  2019  Mercedes-Benz   41.0    0
# 270058     258175       Colorado  2019  Mercedes-Benz   11.0    0
# 270059     258175     California  2019  Mercedes-Benz  252.0    0
# 270060     258175       Virginia  2019  Mercedes-Benz   16.0    0
# 270061     258175       Kentucky  2019  Mercedes-Benz    4.0    0
# 270103     233004     New Jersey  2016  Mercedes-Benz   88.0    3
# 270104     233004       Colorado  2016  Mercedes-Benz   33.0    3
# 270105     233004     California  2016  Mercedes-Benz  601.0    3
# 270106     233004       Virginia  2016  Mercedes-Benz   28.0    3
# 270107     233004       Kentucky  2016  Mercedes-Benz    3.0    3
# 270151     207690     New Jersey  2014  Mercedes-Benz   55.0    5
# 270152     207690       Colorado  2014  Mercedes-Benz   18.0    5
# 270153     207690     California  2014  Mercedes-Benz  347.0    5
# 270154     207690       Virginia  2014  Mercedes-Benz   10.0    5
# 270155     207690       Kentucky  2014  Mercedes-Benz    2.0    5
#
# [31072 rows x 6 columns]

# %%
Make_Vehicle_VIO = Small_VIO['VIO'].sum()
Make_Vehicle_VIO
# Out:
# Make   VehicleID
# Audi   17501          14.0
#        17506          17.0
#        17515          11.0
#        17521          35.0
#        17537           4.0
#        17543          30.0
#        17559          58.0
#        17565          49.0
#        17581          35.0
#        17583          25.0
#        17589          32.0
#        17602          80.0
#        17604          49.0
#        17606          53.0
#        17631          60.0
#        17633          78.0
#        17637          11.0
#        17662         116.0
#        17668          18.0
#        17670          58.0
#        17672          72.0
#        17699          92.0
#        17713          46.0
#        17715          84.0
#        17717          30.0
#        17744         351.0
#        17770         273.0
#        17802         141.0
#        17835          97.0
#        17880          77.0
#                      ...
# Volvo  253807        110.0
#        253808         77.0
#        253809       1938.0
#        253810       4011.0
#        253811       6332.0
#        253812        122.0
#        253814         19.0
#        253824         16.0
#        254149        193.0
#        254150        311.0
#        254151        447.0
#        254152       1544.0
#        254153       2703.0
#        254154       1322.0
#        254155       5706.0
#        254156        502.0
#        254157        376.0
#        256383        752.0
#        256384        313.0
#        256385        358.0
#        256428         58.0
#        256528       1703.0
#        257582         49.0
#        257583         19.0
#        258583        676.0
#        258584         98.0
#        258585        130.0
#        258586        582.0
#        258587        198.0
#        258588        219.0
# Name: VIO, Length: 6241, dtype: float64

# %%
Make_Vehicle_VIO_Summary = pd.DataFrame({"Total VIO": Make_Vehicle_VIO})
Make_Vehicle_VIO_Summary.head()
# Out:
#                 Total VIO
# Make VehicleID
# Audi 17501           14.0
#      17506           17.0
#      17515           11.0
#      17521           35.0
#      17537            4.0

# %%
Make_Vehicle_VIO_Summary['Total VIO'].sum()
# Out:
# 20151507.0

# %%
##Find the Percents##
# %matplotlib notebook
#slices = sorted(Makes_VIO_Summary['Total VIO'])
slices = Makes_VIO_Summary.sort_values(by=['Total VIO'], ascending=False)

#labels = ["Volkswagen", "Mercedes-Benz", "BMW", "Audi", "Volvo", "Land Rover", "Mini", "Porsche", "Jaguar", "Saab"]

#assign the pie sizes, explode the urban city type and apply the labels and colors from above
plt.pie(slices['Total VIO'],autopct="%1.1f%%", shadow=True, startangle=120)
plt.title("% of VIO by Make")
plt.legend(labels=slices.index, bbox_to_anchor=(1,.5), fontsize = 10, title= "Makes", loc="center right", bbox_transform=plt.gcf().transFigure)


#save the pie chart
#plt.savefig("Images/Rides_by_City_Type.png")

#show the pie chart
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
Makes_VIO_Summary
# Out:
#                Total VIO
# Make
# Volkswagen     4723686.0
# Mercedes-Benz  4589723.0
# BMW            4460541.0
# Audi           2047227.0
# Volvo          1524833.0
# Land Rover      726037.0
# Mini            707000.0
# Porsche         680758.0
# Jaguar          456487.0
# Saab            235215.0

# %%
#output clean VIO data to a CSV file
VIO_Data_Complete.to_csv("Output/VIO_Complete.csv", index=False, header=True)

# %%
#print out the first five lines of the ACES data set
ACES_Data.head()
# Out:
#   ShortPartNumber  VehicleID
# 0    000000000884    15200.0
# 1  20388002239040    15200.0
# 2      0375456528    15200.0
# 3       228613009    15200.0
# 4    000010128564    15200.0

# %%
#check data types in ACES dataset
ACES_Data.dtypes
# Out:
# ShortPartNumber     object
# VehicleID          float64
# dtype: object

# %%
#display counts of rows by column to determine if we need to drop any missing values
ACES_Data.count()
# Out:
# ShortPartNumber    2192930
# VehicleID          2191708
# dtype: int64

# %%
#we found that there were blank rows in the VehicleID column, so we are dropping all blanks
ACES_Data_Clean = ACES_Data.dropna(how="any")

#verify that the counts are now correct
ACES_Data_Clean.count()
# Out:
# ShortPartNumber    2191708
# VehicleID          2191708
# dtype: int64

# %%
#Vehicle ID should be int, not float
ACES_Data_Clean['VehicleID'] = ACES_Data_Clean['VehicleID'].astype(int)
#ACES_Data_Clean_1.dtypes
ACES_Data_Clean.dtypes
# Out:
# /Users/whitneycollins/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ShortPartNumber    object
# VehicleID           int64
# dtype: object

# %%
#check data types of the ACES data set
ACES_Data.dtypes
# Out:
# ShortPartNumber     object
# VehicleID          float64
# dtype: object

# %%
#print out the first five lines of the Parts data set
Parts_Data.head()
# Out:
#   ShortPartNumber Main Category   Part Type Name  QTY
# 0        30758260        Engine  Timing Belt Kit   41
# 1         TB234K1        Engine  Timing Belt Kit   14
# 2       159321100        Engine  Timing Belt Kit   10
# 3         TB131K1        Engine  Timing Belt Kit  433
# 4         TB032K1        Engine  Timing Belt Kit   47

# %%
#display counts of rows by column to determine if we need to drop any missing values
Parts_Data.count()
# Out:
# ShortPartNumber    44620
# Main Category      44602
# Part Type Name     44608
# QTY                44620
# dtype: int64

# %%
#we found that there were blank rows in several columns, so we are dropping all blanks
Parts_Data_Clean = Parts_Data.dropna(how="any")

#verify that the counts are now correct
Parts_Data_Clean.count()
# Out:
# ShortPartNumber    44602
# Main Category      44602
# Part Type Name     44602
# QTY                44602
# dtype: int64

# %%
#check data types of the Parts data set
Parts_Data.dtypes
# Out:
# ShortPartNumber    object
# Main Category      object
# Part Type Name     object
# QTY                 int64
# dtype: object

# %%
merge_on_partNumber = pd.DataFrame.merge(Parts_Data_Clean, ACES_Data_Clean, how='inner', on='ShortPartNumber')
merge_on_partNumber.head()
# Out:
#   ShortPartNumber Main Category   Part Type Name  QTY  VehicleID
# 0        30758260        Engine  Timing Belt Kit   41       1510
# 1        30758260        Engine  Timing Belt Kit   41       1506
# 2        30758260        Engine  Timing Belt Kit   41       1511
# 3        30758260        Engine  Timing Belt Kit   41       1513
# 4        30758260        Engine  Timing Belt Kit   41       1507

# %%
#make smaller dataframe from VIO_Data_Complete
VIO_Data_Clean_columns = VIO_Data_Clean[['VehicleID','Make', 'VIO']]

#groupby VehicleID and sum the VIO
VIO_Data_Clean_Sum_VIO = VIO_Data_Clean_columns.groupby(['VehicleID', 'Make'])['VIO'].sum()

#convert to a datafame from a series to be able to merge back to table
Sum_VIO_df = pd.DataFrame(VIO_Data_Clean_Sum_VIO)
Sum_VIO_df.head()
reset_index_df = Sum_VIO_df.reset_index()

#final merge to add VIO sum to merge_on_partNumber dataframe
final_merged_dataframe = pd.DataFrame.merge(merge_on_partNumber, reset_index_df, how='left', on='VehicleID')
final_merged_dataframe.head()
# Out:
#   ShortPartNumber Main Category   Part Type Name  QTY  VehicleID   Make  \
# 0        30758260        Engine  Timing Belt Kit   41       1510  Volvo
# 1        30758260        Engine  Timing Belt Kit   41       1506  Volvo
# 2        30758260        Engine  Timing Belt Kit   41       1511  Volvo
# 3        30758260        Engine  Timing Belt Kit   41       1513  Volvo
# 4        30758260        Engine  Timing Belt Kit   41       1507  Volvo
#
#       VIO
# 0  1727.0
# 1  1855.0
# 2  1136.0
# 3  1222.0
# 4  2946.0

# %%
#print out the first 5 rows of the data set
Population_Data.head()
# Out:
#           State  2018 Population
# 0    California         39776830
# 1         Texas         28704330
# 2       Florida         21312211
# 3      New York         19862512
# 4  Pennsylvania         12823989

# %%
Population_Data.count()
# Out:
# State              51
# 2018 Population    51
# dtype: int64

# %%
State_VIO = VIO_Data_Clean.groupby('State')
State_VIO.head()
# Out:
#      VehicleID                 State  Year        Make   VIO  Age
# 0          545             Wisconsin  1993  Land Rover   2.0   26
# 1          545               Montana  1993  Land Rover   9.0   26
# 2          545         New Hampshire  1993  Land Rover   6.0   26
# 3          545               Wyoming  1993  Land Rover   2.0   26
# 4          545               Florida  1993  Land Rover  14.0   26
# 5          545                 Idaho  1993  Land Rover   4.0   26
# 6          545            Washington  1993  Land Rover  17.0   26
# 7          545              New York  1993  Land Rover  34.0   26
# 8          545            New Jersey  1993  Land Rover   9.0   26
# 9          545          Pennsylvania  1993  Land Rover  12.0   26
# 10         545             Tennessee  1993  Land Rover   7.0   26
# 11         545              Colorado  1993  Land Rover  21.0   26
# 12         545                  Ohio  1993  Land Rover   7.0   26
# 13         545              Virginia  1993  Land Rover   9.0   26
# 14         545              Michigan  1993  Land Rover   3.0   26
# 15         545            California  1993  Land Rover  61.0   26
# 16         545                Oregon  1993  Land Rover   8.0   26
# 17         545               Vermont  1993  Land Rover   5.0   26
# 18         545                 Texas  1993  Land Rover  16.0   26
# 19         545              Missouri  1993  Land Rover   1.0   26
# 20         545              Illinois  1993  Land Rover  11.0   26
# 21         545         Massachusetts  1993  Land Rover  30.0   26
# 22         545            New Mexico  1993  Land Rover   8.0   26
# 23         545               Georgia  1993  Land Rover  13.0   26
# 24         545                  Utah  1993  Land Rover   9.0   26
# 25         545        North Carolina  1993  Land Rover   6.0   26
# 26         545              Oklahoma  1993  Land Rover   2.0   26
# 27         545        South Carolina  1993  Land Rover   4.0   26
# 28         545             Minnesota  1993  Land Rover   4.0   26
# 29         545          South Dakota  1993  Land Rover   1.0   26
# ..         ...                   ...   ...         ...   ...  ...
# 226      15905          Rhode Island  1996  Land Rover   2.0   23
# 227      15905           Connecticut  1996  Land Rover   6.0   23
# 228      15905           Mississippi  1996  Land Rover   7.0   23
# 229      15905                Kansas  1996  Land Rover   8.0   23
# 230      15905  District Of Columbia  1996  Land Rover   2.0   23
# 231      15905                Nevada  1996  Land Rover  15.0   23
# 232      15905              Delaware  1996  Land Rover   2.0   23
# 233      15905              Nebraska  1996  Land Rover   4.0   23
# 234      15905              Maryland  1996  Land Rover   6.0   23
# 235      15905               Indiana  1996  Land Rover  21.0   23
# 236      15905               Arizona  1996  Land Rover  40.0   23
# 237      15905              Arkansas  1996  Land Rover   6.0   23
# 238      15905              Kentucky  1996  Land Rover  13.0   23
# 239      15905                Alaska  1996  Land Rover   7.0   23
# 240      15905                Hawaii  1996  Land Rover   9.0   23
# 241      15905                 Maine  1996  Land Rover   2.0   23
# 242      15905               Alabama  1996  Land Rover   8.0   23
# 243      15905             Louisiana  1996  Land Rover   2.0   23
# 244      15905                  Iowa  1996  Land Rover   7.0   23
# 245      15905         West Virginia  1996  Land Rover   4.0   23
# 246      15905          North Dakota  1996  Land Rover   1.0   23
# 276      15911          South Dakota  1997  Land Rover   2.0   22
# 293      15911               Alabama  1997  Land Rover   9.0   22
# 294      15911             Louisiana  1997  Land Rover   5.0   22
# 295      15911                  Iowa  1997  Land Rover   4.0   22
# 296      15911         West Virginia  1997  Land Rover   2.0   22
# 345      15908         West Virginia  1996  Land Rover  10.0   23
# 346      15908          North Dakota  1996  Land Rover   1.0   23
# 397        556          North Dakota  2000  Land Rover  13.0   19
# 447     238632          North Dakota  2017      Jaguar   4.0    2
#
# [255 rows x 6 columns]

# %%
State_VIO = State_VIO['VIO'].sum()
State_VIO
# Out:
# State
# Alabama                  212723.0
# Alaska                    28225.0
# Arizona                  421964.0
# Arkansas                  76232.0
# California              3738561.0
# Colorado                 411268.0
# Connecticut              378089.0
# Delaware                  63796.0
# District Of Columbia      56949.0
# Florida                 1632867.0
# Georgia                  651452.0
# Hawaii                    84300.0
# Idaho                     80122.0
# Illinois                 729722.0
# Indiana                  232521.0
# Iowa                      88902.0
# Kansas                   102272.0
# Kentucky                 151991.0
# Louisiana                154307.0
# Maine                     88916.0
# Maryland                 435680.0
# Massachusetts            576715.0
# Michigan                 422170.0
# Minnesota                258583.0
# Mississippi               92454.0
# Missouri                 208053.0
# Montana                   48761.0
# Nebraska                  58987.0
# Nevada                   197377.0
# New Hampshire            122854.0
# New Jersey               837380.0
# New Mexico                87028.0
# New York                1168534.0
# North Carolina           555616.0
# North Dakota              14421.0
# Ohio                     517667.0
# Oklahoma                 160979.0
# Oregon                   301574.0
# Pennsylvania             864158.0
# Rhode Island              85598.0
# South Carolina           300961.0
# South Dakota              23525.0
# Tennessee                309895.0
# Texas                   1409170.0
# Utah                     164118.0
# Vermont                   49776.0
# Virginia                 586109.0
# Washington               608369.0
# West Virginia             49428.0
# Wisconsin                232027.0
# Wyoming                   18361.0
# Name: VIO, dtype: float64

# %%
#Data Frame

#put all the variables into a dataframe named school_summary_df
State_VIO_Summary = pd.DataFrame({"Total State VIO": State_VIO})

#remove the display of the index name
#print the dataframe, showing all rows
State_VIO_Summary = State_VIO_Summary.sort_values('Total State VIO', ascending = False)
State_VIO_Summary
# Out:
#                       Total State VIO
# State
# California                  3738561.0
# Florida                     1632867.0
# Texas                       1409170.0
# New York                    1168534.0
# Pennsylvania                 864158.0
# New Jersey                   837380.0
# Illinois                     729722.0
# Georgia                      651452.0
# Washington                   608369.0
# Virginia                     586109.0
# Massachusetts                576715.0
# North Carolina               555616.0
# Ohio                         517667.0
# Maryland                     435680.0
# Michigan                     422170.0
# Arizona                      421964.0
# Colorado                     411268.0
# Connecticut                  378089.0
# Tennessee                    309895.0
# Oregon                       301574.0
# South Carolina               300961.0
# Minnesota                    258583.0
# Indiana                      232521.0
# Wisconsin                    232027.0
# Alabama                      212723.0
# Missouri                     208053.0
# Nevada                       197377.0
# Utah                         164118.0
# Oklahoma                     160979.0
# Louisiana                    154307.0
# Kentucky                     151991.0
# New Hampshire                122854.0
# Kansas                       102272.0
# Mississippi                   92454.0
# Maine                         88916.0
# Iowa                          88902.0
# New Mexico                    87028.0
# Rhode Island                  85598.0
# Hawaii                        84300.0
# Idaho                         80122.0
# Arkansas                      76232.0
# Delaware                      63796.0
# Nebraska                      58987.0
# District Of Columbia          56949.0
# Vermont                       49776.0
# West Virginia                 49428.0
# Montana                       48761.0
# Alaska                        28225.0
# South Dakota                  23525.0
# Wyoming                       18361.0
# North Dakota                  14421.0

# %%
#final merge to add VIO sum to merge_on_partNumber dataframe
final_merged_VIO = pd.DataFrame.merge(Population_Data, State_VIO_Summary, how='left', on='State')
final_merged_VIO.head()
# Out:
#           State  2018 Population  Total State VIO
# 0    California         39776830        3738561.0
# 1         Texas         28704330        1409170.0
# 2       Florida         21312211        1632867.0
# 3      New York         19862512        1168534.0
# 4  Pennsylvania         12823989         864158.0

# %%
#bar graph  by state quantity
# %matplotlib notebook
State_VIO_Summary.plot.bar(figsize=(20,10))

#plt.figure(figsize=(20,10))
plt.show()
plt.tight_layout()
plt.title("VIO by State")
plt.ylabel("VIO")
plt.xlabel("State")


#plt.savefig("Output/State_VIO_Summary.png")
# Out:
# <img src="data:image/png;base64,..." width="1440">
# Text(0.5, -21.75, 'State')

# %%
# Q4 - box - Average age of vehicle by state

Average_Age = VIO_Data_Clean.groupby('State')
Average_Age1 = Average_Age['Age'].mean()
Average_Age1
# Out:
# State
# Alabama                 14.309627
# Alaska                  14.540111
# Arizona                 14.272046
# Arkansas                13.829585
# California              14.334905
# Colorado                14.665461
# Connecticut             14.155931
# Delaware                12.376808
# District Of Columbia    13.786868
# Florida                 14.249258
# Georgia                 14.038815
# Hawaii                  13.543533
# Idaho                   14.427674
# Illinois                13.787023
# Indiana                 13.543454
# Iowa                    14.045857
# Kansas                  13.784864
# Kentucky                13.783419
# Louisiana               12.929359
# Maine                   14.698215
# Maryland                14.254935
# Massachusetts           13.726971
# Michigan                13.884131
# Minnesota               14.186441
# Mississippi             14.429251
# Missouri                14.131593
# Montana                 15.246004
# Nebraska                14.112869
# Nevada                  13.434237
# New Hampshire           13.784395
# New Jersey              14.185899
# New Mexico              13.973405
# New York                14.283206
# North Carolina          13.725078
# North Dakota            13.236167
# Ohio                    14.224893
# Oklahoma                13.200038
# Oregon                  14.536893
# Pennsylvania            14.338328
# Rhode Island            13.331618
# South Carolina          13.804800
# South Dakota            13.594400
# Tennessee               13.889223
# Texas                   13.774874
# Utah                    13.882277
# Vermont                 14.022861
# Virginia                14.204349
# Washington              14.557352
# West Virginia           13.589462
# Wisconsin               14.011980
# Wyoming                 13.823905
# Name: Age, dtype: float64

# %%
# %matplotlib notebook
Average_Age1.plot.bar(figsize=(20,10))


plt.show()
plt.tight_layout()
plt.title("Averge Age of Vehicles by State")
plt.ylabel("Average Age")
plt.xlabel("State")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
Average_Age_by_Type = VIO_Data_Clean.groupby('Make')
Average_Age2 = Average_Age_by_Type['Age'].mean()
Average_Age2
# Out:
# Make
# Audi              9.916117
# BMW              11.315923
# Jaguar           14.845397
# Land Rover        9.356594
# Mercedes-Benz    15.631978
# Mini              5.622101
# Porsche          14.796116
# Saab             21.877011
# Volkswagen       17.122899
# Volvo            15.943907
# Name: Age, dtype: float64

# %%
# %matplotlib notebook
Average_Age2.plot.bar(figsize=(10,5))


#plt.show()
plt.tight_layout()
plt.title("Averge Age of Vehicles by Vehicle Type")
plt.ylabel("Average Age")
plt.xlabel("Type")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
###STATs ANOVA table
#Is there significant difference in vehicle age in cars makes?

# %%
import gmaps
# Google API Key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# pull in data from Kaggle
Lat_Lng = pd.read_csv("Resources/statelatlong.csv")
Lat_Lng
# Out:
#    State   Latitude   Longitude                  City
# 0     AL  32.601011  -86.680736               Alabama
# 1     AK  61.302501 -158.775020                Alaska
# 2     AZ  34.168219 -111.930907               Arizona
# 3     AR  34.751928  -92.131378              Arkansas
# 4     CA  37.271875 -119.270415            California
# 5     CO  38.997934 -105.550567              Colorado
# 6     CT  41.518784  -72.757507           Connecticut
# 7     DE  39.145251  -75.418921              Delaware
# 8     DC  38.899349  -77.014567  District of Columbia
# 9     FL  27.975728  -83.833017               Florida
# 10    GA  32.678125  -83.222976               Georgia
# 11    HI  20.460000 -157.505000                Hawaii
# 12    ID  45.494576 -114.142430                 Idaho
# 13    IL  39.739318  -89.504139              Illinois
# 14    IN  39.766219  -86.441277               Indiana
# 15    IA  41.938317  -93.389798                  Iowa
# 16    KS  38.498779  -98.320078                Kansas
# 17    KY  37.822294  -85.768240              Kentucky
# 18    LA  30.973377  -91.429910             Louisiana
# 19    ME  45.218513  -69.014866                 Maine
# 20    MD  38.806352  -77.268416              Maryland
# 21    MA  42.062940  -71.718067         Massachusetts
# 22    MI  44.943560  -86.415805              Michigan
# 23    MN  46.441859  -93.365515             Minnesota
# 24    MS  32.585106  -89.877220           Mississippi
# 25    MO  38.304662  -92.437099              Missouri
# 26    MT  46.679800 -110.044783               Montana
# 27    NE  41.500819  -99.680902              Nebraska
# 28    NV  38.502032 -117.023060                Nevada
# 29    NH  44.001231  -71.579923         New Hampshire
# 30    NJ  40.143006  -74.731116            New Jersey
# 31    NM  34.166232 -106.026069            New Mexico
# 32    NY  40.705626  -73.979680              New York
# 33    NC  35.214563  -79.891267        North Carolina
# 34    ND  47.467882 -100.302266          North Dakota
# 35    OH  40.190362  -82.669252                  Ohio
# 36    OK  35.309765  -98.716558              Oklahoma
# 37    OR  44.141905 -120.538099                Oregon
# 38    PA  40.994593  -77.604698          Pennsylvania
# 39    RI  41.582728  -71.506451          Rhode Island
# 40    SC  33.625050  -80.947038        South Carolina
# 41    SD  44.212699 -100.247164          South Dakota
# 42    TN  35.830521  -85.978599             Tennessee
# 43    TX  31.169336 -100.076842                 Texas
# 44    UT  39.499761 -111.547028                  Utah
# 45    VT  43.871755  -72.447783               Vermont
# 46    VA  38.003386  -79.458786              Virginia
# 47    WA  38.899349  -77.014567            Washington
# 48    WV  38.920171  -80.181691         West Virginia
# 49    WI  44.786297  -89.826705             Wisconsin
# 50    WY  43.000325 -107.554567               Wyoming

# %%
#make copy of df
Capital_State_VIO = State_VIO_Summary.copy()
Capital_State_VIO
# Out:
#                       Total State VIO
# State
# California                  3738561.0
# Florida                     1632867.0
# Texas                       1409170.0
# New York                    1168534.0
# Pennsylvania                 864158.0
# New Jersey                   837380.0
# Illinois                     729722.0
# Georgia                      651452.0
# Washington                   608369.0
# Virginia                     586109.0
# Massachusetts                576715.0
# North Carolina               555616.0
# Ohio                         517667.0
# Maryland                     435680.0
# Michigan                     422170.0
# Arizona                      421964.0
# Colorado                     411268.0
# Connecticut                  378089.0
# Tennessee                    309895.0
# Oregon                       301574.0
# South Carolina               300961.0
# Minnesota                    258583.0
# Indiana                      232521.0
# Wisconsin                    232027.0
# Alabama                      212723.0
# Missouri                     208053.0
# Nevada                       197377.0
# Utah                         164118.0
# Oklahoma                     160979.0
# Louisiana                    154307.0
# Kentucky                     151991.0
# New Hampshire                122854.0
# Kansas                       102272.0
# Mississippi                   92454.0
# Maine                         88916.0
# Iowa                          88902.0
# New Mexico                    87028.0
# Rhode Island                  85598.0
# Hawaii                        84300.0
# Idaho                         80122.0
# Arkansas                      76232.0
# Delaware                      63796.0
# Nebraska                      58987.0
# District Of Columbia          56949.0
# Vermont                       49776.0
# West Virginia                 49428.0
# Montana                       48761.0
# Alaska                        28225.0
# South Dakota                  23525.0
# Wyoming                       18361.0
# North Dakota                  14421.0

# %%
#Capital_State_VIO = Capital_State_VIO.reset_index()

#merge lat/lng onto state VIO
Capital_State_VIO_merged_dataframe = pd.DataFrame.merge(Lat_Lng, Capital_State_VIO, how='left', left_on = 'City', right_on = 'State')
Capital_State_VIO_merged_dataframe
# Out:
#    State_x   Latitude   Longitude                  City  level_0  index  \
# 0       AL  32.601011  -86.680736               Alabama     24.0   24.0
# 1       AK  61.302501 -158.775020                Alaska     47.0   47.0
# 2       AZ  34.168219 -111.930907               Arizona     15.0   15.0
# 3       AR  34.751928  -92.131378              Arkansas     40.0   40.0
# 4       CA  37.271875 -119.270415            California      0.0    0.0
# 5       CO  38.997934 -105.550567              Colorado     16.0   16.0
# 6       CT  41.518784  -72.757507           Connecticut     17.0   17.0
# 7       DE  39.145251  -75.418921              Delaware     41.0   41.0
# 8       DC  38.899349  -77.014567  District of Columbia      NaN    NaN
# 9       FL  27.975728  -83.833017               Florida      1.0    1.0
# 10      GA  32.678125  -83.222976               Georgia      7.0    7.0
# 11      HI  20.460000 -157.505000                Hawaii     38.0   38.0
# 12      ID  45.494576 -114.142430                 Idaho     39.0   39.0
# 13      IL  39.739318  -89.504139              Illinois      6.0    6.0
# 14      IN  39.766219  -86.441277               Indiana     22.0   22.0
# 15      IA  41.938317  -93.389798                  Iowa     35.0   35.0
# 16      KS  38.498779  -98.320078                Kansas     32.0   32.0
# 17      KY  37.822294  -85.768240              Kentucky     30.0   30.0
# 18      LA  30.973377  -91.429910             Louisiana     29.0   29.0
# 19      ME  45.218513  -69.014866                 Maine     34.0   34.0
# 20      MD  38.806352  -77.268416              Maryland     13.0   13.0
# 21      MA  42.062940  -71.718067         Massachusetts     10.0   10.0
# 22      MI  44.943560  -86.415805              Michigan     14.0   14.0
# 23      MN  46.441859  -93.365515             Minnesota     21.0   21.0
# 24      MS  32.585106  -89.877220           Mississippi     33.0   33.0
# 25      MO  38.304662  -92.437099              Missouri     25.0   25.0
# 26      MT  46.679800 -110.044783               Montana     46.0   46.0
# 27      NE  41.500819  -99.680902              Nebraska     42.0   42.0
# 28      NV  38.502032 -117.023060                Nevada     26.0   26.0
# 29      NH  44.001231  -71.579923         New Hampshire     31.0   31.0
# 30      NJ  40.143006  -74.731116            New Jersey      5.0    5.0
# 31      NM  34.166232 -106.026069            New Mexico     36.0   36.0
# 32      NY  40.705626  -73.979680              New York      3.0    3.0
# 33      NC  35.214563  -79.891267        North Carolina     11.0   11.0
# 34      ND  47.467882 -100.302266          North Dakota     50.0   50.0
# 35      OH  40.190362  -82.669252                  Ohio     12.0   12.0
# 36      OK  35.309765  -98.716558              Oklahoma     28.0   28.0
# 37      OR  44.141905 -120.538099                Oregon     19.0   19.0
# 38      PA  40.994593  -77.604698          Pennsylvania      4.0    4.0
# 39      RI  41.582728  -71.506451          Rhode Island     37.0   37.0
# 40      SC  33.625050  -80.947038        South Carolina     20.0   20.0
# 41      SD  44.212699 -100.247164          South Dakota     48.0   48.0
# 42      TN  35.830521  -85.978599             Tennessee     18.0   18.0
# 43      TX  31.169336 -100.076842                 Texas      2.0    2.0
# 44      UT  39.499761 -111.547028                  Utah     27.0   27.0
# 45      VT  43.871755  -72.447783               Vermont     44.0   44.0
# 46      VA  38.003386  -79.458786              Virginia      9.0    9.0
# 47      WA  38.899349  -77.014567            Washington      8.0    8.0
# 48      WV  38.920171  -80.181691         West Virginia     45.0   45.0
# 49      WI  44.786297  -89.826705             Wisconsin     23.0   23.0
# 50      WY  43.000325 -107.554567               Wyoming     49.0   49.0
#
#            State_y  Total State VIO
# 0          Alabama         212723.0
# 1           Alaska          28225.0
# 2          Arizona         421964.0
# 3         Arkansas          76232.0
# 4       California        3738561.0
# 5         Colorado         411268.0
# 6      Connecticut         378089.0
# 7         Delaware          63796.0
# 8              NaN              NaN
# 9          Florida        1632867.0
# 10         Georgia         651452.0
# 11          Hawaii          84300.0
# 12           Idaho          80122.0
# 13        Illinois         729722.0
# 14         Indiana         232521.0
# 15            Iowa          88902.0
# 16          Kansas         102272.0
# 17        Kentucky         151991.0
# 18       Louisiana         154307.0
# 19           Maine          88916.0
# 20        Maryland         435680.0
# 21   Massachusetts         576715.0
# 22        Michigan         422170.0
# 23       Minnesota         258583.0
# 24     Mississippi          92454.0
# 25        Missouri         208053.0
# 26         Montana          48761.0
# 27        Nebraska          58987.0
# 28          Nevada         197377.0
# 29   New Hampshire         122854.0
# 30      New Jersey         837380.0
# 31      New Mexico          87028.0
# 32        New York        1168534.0
# 33  North Carolina         555616.0
# 34    North Dakota          14421.0
# 35            Ohio         517667.0
# 36        Oklahoma         160979.0
# 37          Oregon         301574.0
# 38    Pennsylvania         864158.0
# 39    Rhode Island          85598.0
# 40  South Carolina         300961.0
# 41    South Dakota          23525.0
# 42       Tennessee         309895.0
# 43           Texas        1409170.0
# 44            Utah         164118.0
# 45         Vermont          49776.0
# 46        Virginia         586109.0
# 47      Washington         608369.0
# 48   West Virginia          49428.0
# 49       Wisconsin         232027.0
# 50         Wyoming          18361.0

# %%
# Store latitude and longitude in locations
locations = Capital_State_VIO_merged_dataframe[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
rating = Capital_State_VIO_merged_dataframe["Total State VIO"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=1000000,
                                 point_radius=2)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Plost as a Hybrid map
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=1000000,
                                 point_radius=2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
